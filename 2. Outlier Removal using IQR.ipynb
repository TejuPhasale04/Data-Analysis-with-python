# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("scholarship.csv")

# %%
data.head(3)
# Out:
#    semester_percentage  scholarship_exam_marks  got_scholarship
# 0                 71.9                      26                1
# 1                 74.6                      38                1
# 2                 75.4                      40                1

# %%
sns.distplot(data["scholarship_exam_marks"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11100\828206924.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["scholarship_exam_marks"])
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='scholarship_exam_marks', ylabel='Density'>

# %%
sns.boxplot(data["scholarship_exam_marks"])
# Out:
# <Axes: >

# %%
Q1=data["scholarship_exam_marks"].quantile(0.25)
Q3=data["scholarship_exam_marks"].quantile(0.75)

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 27.0

# %%
min=Q1-1.5*IQR
max=Q3+1.5*IQR

# %%
min
# Out:
# -23.5

# %%
max
# Out:
# 84.5

# %%
data[(data["scholarship_exam_marks"]<min) | (data["scholarship_exam_marks"]>max)]
# Out:
#      semester_percentage  scholarship_exam_marks  got_scholarship
# 9                   77.5                      94                1
# 40                  66.0                      86                1
# 61                  75.1                      86                0
# 134                 63.3                      93                0
# 162                 78.0                      90                0
# 283                 70.9                      87                0
# 290                 83.8                      87                0
# 311                 69.7                      87                1
# 324                 66.4                      90                0
# 630                 65.6                      96                1
# 685                 60.5                      87                1
# 730                 61.4                      90                1
# 771                 73.1                      86                1
# 846                 69.9                      97                0
# 917                 59.5                     100                0

# %% [markdown]
# ## Trimming

# %%
min=data["scholarship_exam_marks"].min()
max=data["scholarship_exam_marks"].max()

# %%
new_data = data[(data["scholarship_exam_marks"]>min) & (data["scholarship_exam_marks"]<max)]

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(data["scholarship_exam_marks"])

plt.subplot(2,2,2)
sns.boxplot(data["scholarship_exam_marks"])

plt.subplot(2,2,3)
sns.distplot(new_data["scholarship_exam_marks"])

plt.subplot(2,2,4)
sns.boxplot(new_data["scholarship_exam_marks"])

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11100\2007280676.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["scholarship_exam_marks"])
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11100\2007280676.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_data["scholarship_exam_marks"])
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Capping

# %%
data["scholarship_exam_marks"]=np.where(data["scholarship_exam_marks"]>max,max,np.where(data["scholarship_exam_marks"]<min,min,data["scholarship_exam_marks"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data["scholarship_exam_marks"]=np.where(data["scholarship_exam_marks"]>max,max,np.where(data["scholarship_exam_marks"]<min,min,data["scholarship_exam_marks"]))
#
# NameError: name 'np' is not defined
